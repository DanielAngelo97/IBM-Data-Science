# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # __My Jupyter Notebook on IBM Watson Studio__

# %% [markdown]
# #### __Daniel Angelo D. Miradora__
# #### Aspiring Data Scientist

# %% [markdown]
# #### *I am interested in data science because I want to be competitive in the labor market. I also find the work of a data scientist to be fitting for my personality.*

# %% [markdown]
# ### __The following code computes the mean of the given population and prints the output through the defined function.__

# %%
num = [4, 5, 3, 8, 8, 8]

def display():
    print("Mean:", mean)

get_sum = sum(num)
n = len(num)

mean = get_sum/n
display()
# Out:
# Mean: 6.0

# %% [markdown]
# NAME | AGE |   BREED
# ---- | --- | ---------
# Miho |  3  | Jap Spitz
#
# __Grocery List__
# - Dog Food
# - Chew Toy
# - Treats
#
# ![LemonHope.png](attachment:af9f7043-7035-4737-8538-427d0ebefec0.png)
#
# www.google.com
